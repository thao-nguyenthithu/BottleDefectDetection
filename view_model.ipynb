# %%
from ultralytics import YOLO

model = YOLO("runs/detect/yolo11s_run_100_epochs2/weights/best.pt")
print(model.info())
# Out:
# YOLO11s summary: 181 layers, 9,428,953 parameters, 0 gradients, 21.6 GFLOPs
# (181, 9428953, 0, 21.5527936)
